# %%
def MaximaSet(S):
    # Base case: If the set S has only one point, return S
    if len(S) == 1:
        return S

    # Find the median point p in S by lexicographic (r)-coordinates
    p_index = len(S) // 2
    p = sorted(S, key=lambda point: (point[0], point[1]))[p_index]

    # Split S into two sets: L and G
    L = [point for point in S if point < p]
    G = [point for point in S if point >= p]

    # Recursively find maxima sets for L and G
    M1 = MaximaSet(L)
    M2 = MaximaSet(G)

    # Find the lexicographically smallest point in M2
    smallest_point_in_M2 = min(M2, key=lambda point: (point[0], point[1]))

    # Remove points from M1 whose y-coordinates are less than y(smallest_point_in_M2)
    M1 = [point for point in M1 if point[1] >= smallest_point_in_M2[1]]

    # Combine the results
    return M1 + M2
# Out:
# Maxima Set: [(5, 8), (7, 7), (9, 4)]

# %%
import time
time_array = list()
points = [(1, 1), (2, 5), (3, 3), (5, 8), (6, 6), (7, 7), (8, 2), (9, 4)]
points2 =  [(1, 2), (2, 4), (3, 6), (4, 8), (5, 10)]
points3 = [(3, 2), (1, 4), (4, 3), (2, 5), (5, 1)]

 

start_time = time.perf_counter()
print(f"\n{points}\n{MaximaSet(points)}\n")
end_time = time.perf_counter()
time_array.append(end_time - start_time)

start_time = time.perf_counter()
print(f"\n{points2}\n{MaximaSet(points2)}\n")
end_time = time.perf_counter()
time_array.append(end_time - start_time)

start_time = time.perf_counter()
print(f"\n{points3}\n{MaximaSet(points3)}\n")
end_time = time.perf_counter()
time_array.append(end_time - start_time)

print(time_array)
# Out:
# [(1, 1), (2, 5), (3, 3), (5, 8), (6, 6), (7, 7), (8, 2), (9, 4)]
# [(5, 8), (7, 7), (9, 4)]
#
#
# [(1, 2), (2, 4), (3, 6), (4, 8), (5, 10)]
# [(5, 10)]
#
#
# [(3, 2), (1, 4), (4, 3), (2, 5), (5, 1)]
# [(2, 5), (4, 3), (5, 1)]
#
# [0.0005544000014197081, 0.00011150000500492752, 9.620000491850078e-05]

# %%
import matplotlib.pyplot as plt


plt.plot(points, color='r',marker='o',label='points')
plt.plot(points2, color='g',marker='o',label='points2')
plt.plot(points3, color='b',marker='o',label='points3')

plt.title('Input Size VS Execution Time')
plt.grid(True)
plt.legend()
plt.show()

# %% [markdown]
# # Time Complexity: O(n!)
# # Space Complexity: O(n^2)

# %% [markdown]
# n^2 => n*n array
